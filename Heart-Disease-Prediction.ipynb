# %% [markdown]
# # Heart Disease Prediction Using Machine Learning Algorithms

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn import *

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

print("successful import ;)")
# Out:
# successful import ;)

# %% [markdown]
# ## Read Dataset and preprocess the data

# %%
heartData=pd.read_csv("./dataset/heart_data_set.csv");

# %%
heartData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heartData.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# ### Total missing percent of data

# %%
missing_data= heartData.isnull().sum()
total_percentage = (missing_data.sum()/heartData.shape[0]) * 100
print(f'Total percentage of missing data is {round(total_percentage,2)}%')
duplicate=heartData[heartData.duplicated()]
print("Duplicate rows:")
duplicate
#drop duplicate rows
heartData=heartData.drop_duplicates()
# Out:
# Total percentage of missing data is 0.0%
# Duplicate rows:

# %%
rcParams['figure.figsize'] = 10,10
plt.matshow(heartData.corr())
plt.yticks(np.arange(heartData.shape[1]), heartData.columns)
plt.xticks(np.arange(heartData.shape[1]), heartData.columns)
plt.colorbar()

# %%
corr = heartData.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3ca91_row0_col0, #T_3ca91_row1_col1, #T_3ca91_row2_col2, #T_3ca91_row3_col3, #T_3ca91_row4_col4, #T_3ca91_row5_col5, #T_3ca91_row6_col6, #T_3ca91_row7_col7, #T_3ca91_row8_col8, #T_3ca91_row9_col9, #T_3ca91_row10_col10, #T_3ca91_row11_col11, #T_3ca91_row12_col12, #T_3ca91_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3ca91_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_3ca91_row0_col2, #T_3ca91_row2_col0, #T_3ca91_row4_col3, #T_3ca91_row11_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_3ca91_row0_col3, #T_3ca91_row11_col12 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_3ca91_row0_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_3ca91_row0_col5, #T_3ca91_row7_col1, #T_3ca91_row7_col12, #T_3ca91_row8_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_3ca91_row0_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_3ca91_row0_col7, #T_3ca91_row1_col4, #T_3ca91_row4_col6, #T_3ca91_row6_col5, #T_3ca91_row7_col0, #T_3ca91_row8_col2, #T_3ca91_row8_col13, #T_3ca91_row9_col10, #T_3ca91_row10_col9, #T_3ca91_row13_col1, #T_3ca91_row13_col3, #T_3ca91_row13_col8, #T_3ca91_row13_col11, #T_3ca91_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3ca91_row0_col8, #T_3ca91_row1_col11, #T_3ca91_row5_col0, #T_3ca91_row5_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_3ca91_row0_col9, #T_3ca91_row11_col0, #T_3ca91_row12_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_3ca91_row0_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_3ca91_row0_col11 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_3ca91_row0_col12, #T_3ca91_row3_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_3ca91_row0_col13, #T_3ca91_row2_col11, #T_3ca91_row7_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_3ca91_row1_col0, #T_3ca91_row8_col4, #T_3ca91_row12_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_3ca91_row1_col2, #T_3ca91_row12_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_3ca91_row1_col3, #T_3ca91_row1_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_3ca91_row1_col5, #T_3ca91_row11_col7, #T_3ca91_row12_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_3ca91_row1_col7, #T_3ca91_row3_col7, #T_3ca91_row4_col13, #T_3ca91_row6_col12, #T_3ca91_row13_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_3ca91_row1_col8, #T_3ca91_row12_col11 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_3ca91_row1_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_3ca91_row1_col10 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_3ca91_row1_col12, #T_3ca91_row9_col12 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_3ca91_row1_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col1, #T_3ca91_row12_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col5, #T_3ca91_row2_col6, #T_3ca91_row7_col6, #T_3ca91_row10_col0, #T_3ca91_row12_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col7, #T_3ca91_row7_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_3ca91_row2_col8, #T_3ca91_row3_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_3ca91_row2_col10 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_3ca91_row2_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_3ca91_row2_col13 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_3ca91_row3_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_3ca91_row3_col1, #T_3ca91_row9_col2, #T_3ca91_row10_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_3ca91_row3_col2, #T_3ca91_row6_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_3ca91_row3_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_3ca91_row3_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_3ca91_row3_col8, #T_3ca91_row4_col8, #T_3ca91_row5_col2, #T_3ca91_row8_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_3ca91_row3_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_3ca91_row3_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_3ca91_row3_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_3ca91_row3_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_3ca91_row4_col0, #T_3ca91_row9_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_3ca91_row4_col1, #T_3ca91_row7_col5, #T_3ca91_row8_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3ca91_row4_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_3ca91_row4_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_3ca91_row4_col7, #T_3ca91_row5_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_3ca91_row4_col9, #T_3ca91_row6_col13 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_3ca91_row4_col10, #T_3ca91_row10_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_3ca91_row4_col11 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_3ca91_row4_col12 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_3ca91_row5_col1, #T_3ca91_row6_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_3ca91_row5_col3, #T_3ca91_row5_col13 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_3ca91_row5_col4, #T_3ca91_row6_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_3ca91_row5_col6, #T_3ca91_row11_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3ca91_row5_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_3ca91_row5_col10, #T_3ca91_row6_col9, #T_3ca91_row12_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_3ca91_row5_col11, #T_3ca91_row11_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_3ca91_row5_col12, #T_3ca91_row6_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_3ca91_row6_col0, #T_3ca91_row8_col10, #T_3ca91_row9_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_3ca91_row6_col2, #T_3ca91_row11_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_3ca91_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_3ca91_row6_col4, #T_3ca91_row7_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_3ca91_row6_col10 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_3ca91_row7_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_3ca91_row7_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3ca91_row7_col10 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_3ca91_row7_col11, #T_3ca91_row10_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_3ca91_row7_col13 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_3ca91_row8_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_3ca91_row8_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_3ca91_row8_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_3ca91_row8_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_3ca91_row8_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_3ca91_row8_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_3ca91_row9_col1, #T_3ca91_row9_col3, #T_3ca91_row12_col10 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_3ca91_row9_col5, #T_3ca91_row9_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_3ca91_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_3ca91_row9_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_3ca91_row9_col11 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_3ca91_row9_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_3ca91_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_3ca91_row10_col3, #T_3ca91_row10_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3ca91_row10_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_3ca91_row10_col6, #T_3ca91_row11_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }

# %% [markdown]
# ### Count of each Target Class

# %%
rcParams['figure.figsize'] = 8,6
plt.bar(heartData['target'].unique(), heartData['target'].value_counts(), color = ['black', 'silver'])
plt.xticks([0, 1])
plt.xlabel('Target Classes')
plt.ylabel('Count')
plt.title('Count of each Target Class')
# Out:
# Text(0.5, 1.0, 'Count of each Target Class')

# %% [markdown]
# ## Devide data into trainng testing classes

# %%
X = heartData.drop(['target'], axis = 1)
y = heartData['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)
print("XTrain->",X_train.shape[0],"XTest->",X_test.shape[0], "YTrain->",y_train.shape[0], "XTrain->",y_test.shape[0])
# Out:
# XTrain-> 211 XTest-> 91 YTrain-> 211 XTrain-> 91

# %% [markdown]
# # Model Building

# %% [markdown]
# # KNN Algorithm

# %%
#dated::10/0/2022
knn_scores = []
for k in range(2,21):
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    knn_classifier.fit(X_train.values, y_train.values)
    knn_score=round(knn_classifier.score(X_test.values, y_test.values),2)
    knn_scores.append(knn_score)


knn_classifier = KNeighborsClassifier(n_neighbors = 5)
knn_classifier.fit(X_train, y_train)
knn_score=knn_classifier.predict(X_test)
print(classification_report(y_test,knn_score))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.49      0.55        41
#            1       0.64      0.76      0.70        50
#
#     accuracy                           0.64        91
#    macro avg       0.63      0.62      0.62        91
# weighted avg       0.64      0.64      0.63        91

# %% [markdown]
# ## KNN Plot

# %%
plt.plot([k for k in range(2, 21)], knn_scores, color = 'red')
for i in range(2,21):
    plt.text(i, knn_scores[i-2], (i, knn_scores[i-2]))
plt.xticks([i for i in range(2, 21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('KNN Scores for different K neighbouras')
# Out:
# Text(0.5, 1.0, 'KNN Scores for different K neighbouras')

# %%
print(knn_scores)
print(max(knn_scores))
# Out:
# [0.48, 0.6, 0.63, 0.64, 0.69, 0.65, 0.68, 0.67, 0.67, 0.7, 0.68, 0.68, 0.69, 0.7, 0.67, 0.67, 0.64, 0.66, 0.63]
# 0.7

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 11)
knn_classifier.fit(X_train.values, y_train.values)
check_data_by_sudhansu = np.array([[52,1,0,125,212,0,1,168,0,1,2,2,3]])
#check_data_by_sudhansu = np.array([[71,0,0,112,149,0,1,100,0,1.6,1,0,2]]) o/p=1
prediction_result = knn_classifier.predict(check_data_by_sudhansu)
print("Prediction: {}".format(prediction_result))
# Out:
# Prediction: [1]

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.metrics import accuracy_score

svc_scores = []
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for i in range(len(kernels)):
    svc_classifier = SVC(kernel = kernels[i])
    svc_classifier.fit(X_train.values, y_train.values)
    svc_scores.append(round(svc_classifier.score(X_test.values, y_test.values),2))

svc_classifier = SVC(kernel = kernels[0])
svc_classifier.fit(X_train.values, y_train.values)
svc_prediction_result=svc_classifier.predict(X_test.values)
#print(svc_prediction_result)
print(accuracy_score(y_test.values,svc_prediction_result))
# Out:
# 0.7912087912087912

# %%
colors = rainbow(np.linspace(0, 1, len(kernels)))
plt.bar(kernels, svc_scores, color = colors)
for i in range(len(kernels)):
    plt.text(i, svc_scores[i], svc_scores[i])
plt.xlabel('Kernels')
plt.ylabel('Scores')
plt.title('SVM scores Activation function wise...')
# Out:
# Text(0.5, 1.0, 'SVM scores Activation function wise...')

# %% [markdown]
# # Decision Tree

# %%
dt_scores = []
for i in range(1, len(X.columns) + 1):
    dt_classifier = DecisionTreeClassifier(max_features = i, random_state = 0)
    dt_classifier.fit(X_train.values, y_train.values)
    dt_scores.append(round(dt_classifier.score(X_test.values, y_test.values),2))
print("Done")
# Out:
# Done

# %%
print(dt_scores)
# Out:
# [0.66, 0.7, 0.74, 0.71, 0.71, 0.68, 0.7, 0.73, 0.7, 0.71, 0.74, 0.74, 0.74]

# %%
dt_classifier = DecisionTreeClassifier(max_features = 13, random_state = 0)
dt_classifier.fit(X_train.values, y_train.values)
# Out:
# DecisionTreeClassifier(max_features=13, random_state=0)

# %%
plt.plot([i for i in range(1, len(X.columns) + 1)], dt_scores, color = 'green')
for i in range(1, len(X.columns) + 1):
    plt.text(i, dt_scores[i-1], (i, dt_scores[i-1]))
plt.xticks([i for i in range(1, len(X.columns) + 1)])
plt.xlabel('Max features')
plt.ylabel('Scores')
plt.title('Decision Tree Classifier scores for different number of maximum features')
# Out:
# Text(0.5, 1.0, 'Decision Tree Classifier scores for different number of maximum features')

# %% [markdown]
# # Random Forest

# %%
rf_scores = []
estimators = [10, 20,100, 200, 500]
for i in estimators:
    rf_classifier = RandomForestClassifier(n_estimators = i, random_state = 0)
    rf_classifier.fit(X_train.values, y_train.values)
    rf_scores.append(round(rf_classifier.score(X_test.values, y_test.values),2))

# %%
colors = rainbow(np.linspace(0, 1, len(estimators)))
plt.bar([i for i in range(len(estimators))], rf_scores, color = colors, width = 0.8)
for i in range(len(estimators)):
    plt.text(i, rf_scores[i], rf_scores[i])
plt.xticks(ticks = [i for i in range(len(estimators))], labels = [str(estimator) for estimator in estimators])
plt.xlabel('Number of estimators')
plt.ylabel('Scores')
plt.title('Random Forest Classifier scores for different number of estimators')
# Out:
# Text(0.5, 1.0, 'Random Forest Classifier scores for different number of estimators')

# %%
rf_model = RandomForestClassifier(n_estimators = 10, random_state = 0)
rf_model.fit(X_train.values, y_train.values)
rf_model_result=rf_classifier.predict(X_test.values)
print(accuracy_score(y_test,rf_model_result))
# Out:
# 0.7582417582417582

# %% [markdown]
# # Logistic Regression

# %%
logistic_model = LogisticRegression()
logistic_model.fit(X_train.values, y_train.values)
logistic_model_prediction=logistic_model.predict(X_test.values)
print(accuracy_score(y_test.values,logistic_model_prediction))
print(classification_report(y_test.values,logistic_model_prediction))
# Out:
# 0.8131868131868132
#               precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77        41
#            1       0.79      0.90      0.84        50
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.80      0.81        91
# weighted avg       0.82      0.81      0.81        91

# %%
import pickle
all_models=[rf_model,logistic_model,dt_classifier,svc_classifier,knn_classifier]
#pickle.dump(logistic_model,open("models.pkl","wb"))
#pickle.dump(rf_classifier,open("models.pkl","wb"))
with open("models.pkl", 'wb') as files:
    pickle.dump(all_models, files)
print("Done")
# Out:
# Done

# %% [markdown]
# # Save Trained Models

# %%
open_file = open("models.pkl", "rb")
loaded_list = pickle.load(open_file)
print(loaded_list)
open_file.close()
print("Done")
# Out:
# [RandomForestClassifier(n_estimators=10, random_state=0), LogisticRegression(), DecisionTreeClassifier(max_features=13, random_state=0), SVC(kernel='linear'), KNeighborsClassifier(n_neighbors=11)]
# Done
